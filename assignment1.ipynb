# %%
print("sakthi")
# Out:
# sakthi

# %%
x=int(input("enter first number"))          # subraction
y=int(input("enter second number"))
c=x-y
print("the sub is",c)
# Out:
# enter first number78
# enter second number65
# the sub is 13

# %%
         
                                            
 x=int(input("enter first number"))           #multipication
 y=int(input("enter second number"))  
 c=x*y
 print("the mul is",c)

# %%
a=int(input("enter the first number"))             #division
b=int(input("enter the second number"))
c=a/b
print('the div is',c)
# Out:
# enter the first number56
# enter the second number112
# the div is 0.5
