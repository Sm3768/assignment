# %%
#ASSIGNMENT

# %%
tickets = 3
participants = ["kamatchi", "munusamy", "sakthi"]
for i in range(3):
 print(participants)
# Out:
# ['kamatchi', 'munusamy', 'sakthi']
# ['kamatchi', 'munusamy', 'sakthi']
# ['kamatchi', 'munusamy', 'sakthi']

# %%
import random
n= random.randint(0,tickets-1)
participants[n]
# Out:
# 'sakthi'
